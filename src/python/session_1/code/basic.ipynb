# %%
x=10

# %%
print("my name is {0} , my age is {1}" .format("amit",30))
print("my name is {} , my age is {}" .format("amit",30))
print("my name is {x} , my age is {y}" .format(x = "amit",y = 30))
# Out:
# my name is amit , my age is 30
# my name is amit , my age is 30
# my name is amit , my age is 30

# %%
name = "amit"
age = 30 
print(f"my name is {name} , my age is {age}")
# Out:
# my name is amit , my age is 30

# %%
name = "youssef"
age = 21 
coursename = "depi_ml"
print(f"my name is {name} , my age is{age} , my i am engaged in learning {coursename}")
# Out:
# my name is youssef , my age is21 , my i am engaged in learning depi_ml

# %%
name = "amit learning"
print(name[0:13:3])
# Out:
# ateng

# %%
name = "amit learning"
print(name.upper())
# Out:
# AMIT LEARNING

# %%
name = "AMIT LEARNING"
print(name.lower())
# Out:
# amit learning

# %%
name = "amit learning"
print(name.replace("amit", "hello"))
# Out:
# hello learning

# %%
name = "amit learning"
print(name.capitalize())
# Out:
# Amit learning

# %%
print("hello\nWorld")
# Out:
# hello
# World

# %%
print("hello\tWorld")
# Out:
# hello	World

# %%
len(name)
# Out:
# 13

# %%
x = 2
print(hex(id(x)))
# Out:
# 0x1b119120110
