# %%
name = "&&&**$gnirtS PLIO!!@1234"

print(name[6:17])
reversed_word1 = name[6:12][::-1]
print(reversed_word1)

Replace_word2 = name[13:17]
fixed_word2 = Replace_word2.replace("I","E").replace("O","U")
print(fixed_word2)

print(reversed_word1 , fixed_word2)
# Out:
# gnirtS PLIO
# String
# PLEU
# String PLEU
