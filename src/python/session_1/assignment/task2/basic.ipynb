# %%
email =  "Amit_ml@gmail.edu"

if email.count("@") != 1:
 print("invalid email") 

elif "." not in email.split("@")[1] :

 print("Invalid email") 

else :  

 username = email.split("@")[0] 

 afterat = email.split("@")[1] 
 lastdot =  afterat.rfind(".")
 domain = afterat[:lastdot]

 if email.endswith(".com"): 
  domain_type="commerical Domain"

 elif email.endswith(".edu") :

  domain_type = "educational Domain"
 else:
  domain_type = "other domain"

 print("Username:",username )
 print("Domain:",domain )
 print("Domain Type:",domain_type)
# Out:
# Username: Amit_ml
# Domain: gmail
# Domain Type: educational Domain

# %%
email = "Amit_ml@gmail.edu"



if email.count("@") != 1:
    print("Invalid email")

elif "." not in email.split("@")[1]:
    print("Invalid email")

else:
  
    username = email.split("@")[0]

   
    after_at = email.split("@")[1]       
    last_dot_index = after_at.rfind(".") 
    domain = after_at[:last_dot_index]  

    if email.endswith(".com"):
        domain_type = "Commercial Domain"
    elif email.endswith(".edu"):
        domain_type = "Educational Domain"
    else:
        domain_type = "Other Domain"

   

    print("Username:", username)
    print("Domain:", domain)
    print("Domain Type:", domain_type)
# Out:
# Username: Amit_ml
# Domain: gmail
# Domain Type: Educational Domain

# %%
list_1 = [1,2,3,4,"depi", "learning" , True , ["ml", "dl", "ds"]]

# %%
type(list_1)
list_1[7][1]
# Out:
# 'dl'

# %%
list_2 = ['amit', 'learning', "python"]
list_2.append("ml")
list_2
# Out:
# ['amit', 'learning', 'python', 'ml']

# %%
list_2.insert(0 ,"depi")
list_2
# Out:
# ['depi', 'depi', 'depi', 'amit', 'learning', 'python', 'ml']

# %%
list_1 = [1 , 2 , 3]
list_2 = [3 , 4 , 5]
list_1 + list_2
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
list_one = ["amit" , "learning", "python"]
list_one.pop()
print(list_one)
# Out:
# ['amit', 'learning']

# %%
list_one = ["amit" , "learning", "python"]
list_one.pop(0)
print(list_one)
# Out:
# ['learning', 'python']

# %%
tuple_1 =("depi", "machine", "learning")
tuple_1[1]
# Out:
# 'machine'

# %%
num1 = int(input("enter num1 : "))
num2 = int(input("enter num2 : "))

addition = num1 + num2 
print("Addition:", addition)
subtraction = num1 - num2 
print("Subtraction:", subtraction)
multiplication = num1 * num2
print("Multiplication:", multiplication)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 num1 = int(input("enter num1 : "))
#       3 num2 = int(input("enter num2 : "))
#       5 addition = num1 + num2
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
# ...

# %%
num1 = 5
num2 = 4

addition = num1 + num2 
subtraction = num1 - num2 
multiplication = num1 * num2
division = num1 / num2 
if num2 != 0 : 
 division = num1 / num2 
else :
 division = "can't divid by zero "


print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
# Out:
# Addition: 9
# Subtraction: 1
# Multiplication: 20
# Division: 1.25
