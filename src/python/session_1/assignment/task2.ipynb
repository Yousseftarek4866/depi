# %%
name = "###!!@mocleW EPGTQ!!!6789"

print(name[6:18])

reversed_word1 = name[6:12][::-1]
print("Reversed word1 :", reversed_word1)

fixed_word2 = name[13:18]
fixed_word2 = fixed_word2.replace("E" , "")
print(fixed_word2)

print(reversed_word1 , fixed_word2)
# Out:
# mocleW EPGTQ
# Reversed word1 : Welcom
# PGTQ
# Welcom PGTQ
