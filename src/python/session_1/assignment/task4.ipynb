# %%
name ="##$$$@!yalpstcejorp EPUVT****9887"
print(name[7:25])

reversed_word1 = name[7:19][::-1]
print(reversed_word1)

Replace_word2 = name[20:25]
fixed_word2 = Replace_word2.replace("E" , "A").replace("U" , "O")
print (fixed_word2)

print(reversed_word1 , fixed_word2)
# Out:
# yalpstcejorp EPUVT
# projectsplay
# APOVT
# projectsplay APOVT
