# %%
def reverse_vocab(s) : 
    st_1 = s.split(" ")
    new_st = st_1[::-1]
    new_str = ''.join(new_st)
    return new_st
s = "hello world"
reverse_vocab(s)
# Out:
# ['world', 'hello']

# %%
# convert el function to class 
class PasswordGenerator:
    import random

    def __init__(self):
        self.length = 8
        self.characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"

    def generate_passcode(self, length):
        chars = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
        password = ""

        for _ in range(self.length):
            password += random.choice(chars)

        return password


if __name__ == "__main__":
    generator = PasswordGenerator()
    random_password = generator.generate_passcode(8) 
    print(random_password)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 21
#      19 if __name__ == "__main__":
#      20     generator = PasswordGenerator()
# ---> 21     random_password = generator.generate_passcode(8)
#      22     print(random_password)
#
# Cell In[3], line 14, in PasswordGenerator.generate_passcode(self, length)
#      11 password = ""
#      13 for _ in range(self.length):
# ---> 14     password += random.choice(chars)
#      16 return password
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'choice'

# %%
# create a program that generate a random password of a given length 
import random 

def generate_passcode(length) : 
    chars = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""
    for _ in range(length): 
    
      password += random.choice(chars) 
    
    return password 
password_length = 8 
print(generate_passcode(password_length))
# Out:
# OJmf4kiR

# %%
# write a python to find all the unique words and count the frequancy of occurance from a given list of strings 
words = ["welcome" , "ali" , "hi" , "no" , "ali" , "no" , "ali"]
unique_words = set(words) 
counts = {word : 0 for word in unique_words}
for i in unique_words : 
 for j in words : 
   if i == j :
     counts[i] += 1
counts
# Out:
# {'ali': 3, 'welcome': 1, 'no': 2, 'hi': 1}

# %%
words = ["welcome" , "ali" , "hi" , "no" , "ali" , "no" , "ali"]
def counts_words(words) : 
  unique_words = set(words)  
counts = {word : 0 for word in unique_words}
for i in unique_words : 
 for j in words : 
        if i == j :
           counts[i] += 1   
 counts
print(counts_words(counts))
# Out:
# <function __main__.counts_words(words)>

# %%
#chatbot
import random
responses = {
     "hello"  : ["hello!","Hi there!","Greetings!"],
    "how are you" :["I'm doing well, thank you", "i'm fine, how are you?"],
    "goodbye" :["Goodbye", "see you later", "farewell!"],
    "default" : ["i'm sorry, i did not understand. ","could you please rephrase that?"]

}
def get_response(user_input) : 
    for key in responses : 
        if key in user_input : 
            return random.choice(responses[key])
    return random.choice(responses["default"])  
  




def chatbot() : 
    print("chatbot : how can i help you ?")

    while True: 
        user_input = input("user:    " ).lower()
        response = get_response(user_input)
        print("chatbot:  " , response)

        if user_input == "goodbye" : 
            break

# %%
chatbot()
# Out:
# chatbot : how can i help you ?
# chatbot:   Hi there!
# chatbot:   Goodbye

# %%
class Student_Info:

  student_name = "depi"
  std_age = 21 
  std_gpa = 3.99 
  gender = "male"
     

  def std_info(self): 
    print("hello world") 
s1 = Student_Info()  
s1.student_name = "AMIT"
s1.std_info()
# Out:
# hello world

# %%
class test : 
    def info(self) : 
        print(self)

# %%
x = test()
print(x)

# %%
x.info()

# %%
class Student : 

    def __init__(self) : 
         print("hello world")
s1 = Student()
# Out:
# hello world
